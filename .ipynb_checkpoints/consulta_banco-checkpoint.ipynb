# %%
import pymongo
from pymongo import MongoClient
client = MongoClient("mongodb+srv://root:root@cluster0-0rj95.mongodb.net/test?retryWrites=true")
db = client.registros

# %%
ret = db.registros.aggregate([
    { '$match':{'Filme': 'Não'} },
    {
        '$project': {        
            "imdb": {            
                '$arrayElemAt':[{'$split': ["$imdb" , " "]}, 0]                
            },
            'f':'$Filme'
        }
    }, 
    {'$group': {'_id':'$imdb'}}
    
])

for r in ret:
    print(r)
print('Fim')
# Out:
# {'_id': 'tt8577458'}
# {'_id': 'tt8784324'}
# {'_id': 'tt0397306'}
# {'_id': 'tt4474344'}
# {'_id': 'tt9775360'}
# {'_id': 'tt5296406'}
# {'_id': 'tt8792866'}
# {'_id': 'tt8694364'}
# {'_id': 'tt3839822'}
# {'_id': 'tt0460681'}
# {'_id': 'tt7661390'}
# {'_id': 'tt7414406'}
# {'_id': 'tt5766086'}
# {'_id': 'tt1869454'}
# {'_id': 'tt11307176'}
# {'_id': 'tt4477976'}
# {'_id': 'tt9446688'}
# {'_id': 'tt3920596'}
# {'_id': 'tt7048386'}
# {'_id': 'tt6076694'}
# {'_id': 'tt8690478'}
# {'_id': 'tt7491982'}
# {'_id': 'tt7569592'}
# {'_id': 'tt10423460'}
# {'_id': 'tt9460858'}
# {'_id': 'tt11058644'}
# {'_id': 'tt10145110'}
# {'_id': 'tt7768192'}
# {'_id': 'tt5827228'}
# {'_id': 'tt0489974'}
# {'_id': 'tt6763664'}
# {'_id': 'tt6487482'}
# {'_id': 'tt11390530'}
# {'_id': 'tt5722214'}
# {'_id': 'tt7150060'}
# {'_id': 'tt8879940'}
# {'_id': 'tt11120674'}
# {'_id': 'tt10234362'}
# {'_id': 'tt12879522'}
# {'_id': 'tt6586344'}
# {'_id': 'tt9185110'}
# {'_id': 'tt4209256'}
# {'_id': 'tt3793630'}
# {'_id': 'tt10919486'}
# {'_id': 'tt3921180'}
# {'_id': 'tt4378376'}
# {'_id': 'tt11928982'}
# {'_id': 'tt6483832'}
# {'_id': 'tt11974516'}
# {'_id': 'tt13044528'}
# {'_id': 'tt8285216'}
# {'_id': 'tt1898069'}
# {'_id': 'tt7599942'}
# {'_id': 'tt6586318'}
# {'_id': 'tt9522354'}
# {'_id': 'tt6038954'}
# {'_id': 'tt5396394'}
# {'_id': 'tt7255502'}
# {'_id': 'tt5753856'}
# {'_id': 'tt4786824'}
# {'_id': 'tt7235466'}
# {'_id': 'tt5615700'}
# {'_id': 'tt10715172'}
# {'_id': 'tt9153270'}
# {'_id': 'tt9856336'}
# {'_id': 'tt4016454'}
# {'_id': 'tt8543390'}
# {'_id': 'tt11170862'}
# {'_id': 'tt6548228'}
# {'_id': 'tt0944947'}
# {'_id': 'tt4941240'}
# {'_id': 'tt4131818'}
# {'_id': 'tt7668518'}
# {'_id': 'tt2364582'}
# {'_id': 'tt8404094'}
# {'_id': 'tt8961530'}
# {'_id': 'tt4998350'}
# {'_id': 'tt10196390'}
# {'_id': 'tt5651844'}
# {'_id': 'tt1074206'}
# {'_id': 'tt7608248'}
# {'_id': 'tt8746478'}
# {'_id': 'tt8550800'}
# {'_id': 'tt5057054'}
# {'_id': 'tt0157246'}
# {'_id': 'tt8772296'}
# {'_id': 'tt11131980'}
# {'_id': 'tt3007572'}
# {'_id': 'tt8965666'}
# {'_id': 'tt6064882'}
# {'_id': 'tt7414954'}
# {'_id': 'tt2861424'}
# {'_id': 'tt8403664'}
# {'_id': 'tt2384811'}
# {'_id': 'tt9011124'}
# {'_id': 'tt2085059'}
# {'_id': 'tt9418572'}
# {'_id': 'tt0197139'}
# {'_id': 'tt6233618'}
# {'_id': 'tt10540562'}
# {'_id': 'tt5743796'}
# {'_id': 'tt12735384'}
# {'_id': 'tt13255112'}
# {'_id': 'tt9581768'}
# {'_id': 'tt8001106'}
# {'_id': 'tt9850952'}
# {'_id': 'tt8565136'}
# {'_id': 'tt5290382'}
# {'_id': 'tt6693154'}
# {'_id': 'tt2304589'}
# {'_id': 'tt3230854'}
# {'_id': 'tt8855592'}
# {'_id': 'tt2357547'}
# {'_id': 'tt8693266'}
# {'_id': 'tt4667888'}
# {'_id': 'tt8518136'}
# {'_id': 'tt4524056'}
# {'_id': 'tt6873658'}
# {'_id': 'tt3743822'}
# {'_id': 'tt9437310'}
# {'_id': 'tt3006802'}
# {'_id': 'tt1013119'}
# {'_id': 'tt10062292'}
# {'_id': 'tt10451106'}
# {'_id': 'tt7263154'}
# {'_id': 'tt6077448'}
# {'_id': 'tt8470764'}
# {'_id': 'tt7562112'}
# {'_id': 'tt8652722'}
# {'_id': 'tt0386676'}
# {'_id': 'tt5691670'}
# {'_id': 'tt1190634'}
# {'_id': 'tt11426660'}
# {'_id': 'tt11958922'}
# {'_id': 'tt4607112'}
# {'_id': 'tt9310400'}
# {'_id': 'tt8005176'}
# {'_id': 'tt9815502'}
# {'_id': 'tt7972480'}
# {'_id': 'tt7736544'}
# {'_id': 'tt3835080'}
# {'_id': 'tt4192782'}
# {'_id': 'tt8420184'}
# {'_id': 'tt10228550'}
# {'_id': 'tt8476166'}
# {'_id': 'tt0115200'}
# {'_id': 'tt1043813'}
# {'_id': 'tt8523042'}
# {'_id': 'tt5348176'}
# {'_id': 'tt4955642'}
# {'_id': 'tt8510382'}
# {'_id': 'tt9077530'}
# {'_id': 'tt0436992'}
# {'_id': 'tt10482370'}
# {'_id': 'tt7845644'}
# {'_id': 'tt4574334'}
# {'_id': 'tt3489184'}
# {'_id': 'tt9184994'}
# {'_id': 'tt10075318'}
# {'_id': 'tt1641384'}
# {'_id': 'tt3032476'}
# {'_id': 'tt10289938'}
# {'_id': 'tt6632666'}
# {'_id': 'tt2891574'}
# {'_id': 'tt7243884'}
# {'_id': 'tt7440732'}
# {'_id': 'tt8362852'}
# {'_id': 'tt8579674'}
# {'_id': 'tt9498102'}
# {'_id': 'tt9077192'}
# {'_id': 'tt8417308'}
# {'_id': 'tt3673794'}
# {'_id': 'tt6045840'}
# {'_id': 'tt5711280'}
# {'_id': 'tt1600194'}
# {'_id': 'tt6474378'}
# {'_id': 'tt10243628'}
# {'_id': 'tt10267146'}
# {'_id': 'tt6913288'}
# {'_id': 'tt3228904'}
# {'_id': 'tt7587362'}
# {'_id': 'tt7736572'}
# {'_id': 'tt6794990'}
# {'_id': 'tt6829180'}
# {'_id': 'tt0364845'}
# {'_id': 'tt8001788'}
# {'_id': 'tt1520211'}
# {'_id': 'tt4705002'}
# {'_id': 'tt11833388'}
# {'_id': 'tt5673782'}
# {'_id': 'tt5165368'}
# {'_id': 'tt10448912'}
# {'_id': 'tt6053512'}
# {'_id': 'tt6048596'}
# {'_id': 'tt0121955'}
# {'_id': 'tt7555294'}
# {'_id': 'tt10875696'}
# {'_id': 'tt7203552'}
# {'_id': 'tt7529770'}
# {'_id': 'tt7413448'}
# {'_id': 'tt10207090'}
# {'_id': 'tt8714904'}
# {'_id': 'tt4687880'}
# {'_id': 'tt8367184'}
# {'_id': 'tt10795658'}
# {'_id': 'tt5197820'}
# {'_id': 'tt9645942'}
# {'_id': 'tt10380934'}
# {'_id': 'tt2306299'}
# {'_id': 'tt9050352'}
# {'_id': 'tt8201186'}
# {'_id': 'tt7671070'}
# {'_id': 'tt7660850'}
# {'_id': 'tt4154664'}
# {'_id': 'tt10228230'}
# {'_id': 'tt7923832'}
# {'_id': 'tt8337014'}
# {'_id': 'tt7817340'}
# {'_id': 'tt1632701'}
# {'_id': 'tt1910645'}
# {'_id': 'tt11475228'}
# {'_id': 'tt4655480'}
# {'_id': 'tt9641192'}
# {'_id': 'tt11275208'}
# {'_id': 'tt3663490'}
# {'_id': 'tt9244578'}
# {'_id': 'tt7423322'}
# {'_id': 'tt7721046'}
# {'_id': 'tt7520794'}
# {'_id': 'tt1553656'}
# {'_id': 'tt6439752'}
# {'_id': 'tt10049610'}
# {'_id': 'tt5951188'}
# {'_id': 'tt8860450'}
# {'_id': 'tt1236246'}
# {'_id': 'tt10487072'}
# {'_id': 'tt0988824'}
# {'_id': 'tt7140432'}
# {'_id': 'tt7412482'}
# {'_id': 'tt0475784'}
# {'_id': 'tt4643084'}
# {'_id': 'tt9654086'}
# {'_id': 'tt5024912'}
# {'_id': 'tt8961508'}
# {'_id': 'tt10982034'}
# {'_id': 'tt9770286'}
# {'_id': 'tt11165002'}
# {'_id': 'tt9184592'}
# {'_id': 'tt7137906'}
# {'_id': 'tt5114356'}
# {'_id': 'tt1442437'}
# {'_id': 'tt7211618'}
# {'_id': 'tt10970552'}
# {'_id': 'tt2856466'}
# {'_id': 'tt5194792'}
# {'_id': 'tt8433216'}
# {'_id': 'tt7456722'}
# {'_id': 'tt7938588'}
# {'_id': 'tt4254242'}
# {'_id': 'tt6226232'}
# {'_id': 'tt4052886'}
# {'_id': 'tt7472896'}
# {'_id': 'tt0452046'}
# {'_id': 'tt8690440'}
# {'_id': 'tt10732104'}
# {'_id': 'tt2379713'}
# {'_id': 'tt10302548'}
# {'_id': 'tt7913450'}
# {'_id': 'tt8074528'}
# {'_id': 'tt11269886'}
# {'_id': 'tt5536400'}
# {'_id': 'tt7573024'}
# {'_id': 'tt1843230'}
# {'_id': 'tt8682948'}
# {'_id': 'tt9827854'}
# {'_id': 'tt10888876'}
# {'_id': 'tt10473150'}
# {'_id': 'tt10148174'}
# {'_id': 'tt10037034'}
# {'_id': 'tt3205802'}
# {'_id': 'tt6903284'}
# {'_id': 'tt9731242'}
# {'_id': 'tt9228950'}
# {'_id': 'tt2191671'}
# {'_id': 'tt9117054'}
# {'_id': 'tt7725422'}
# {'_id': 'tt10549212'}
# {'_id': 'tt2467372'}
# {'_id': 'tt2356777'}
# {'_id': 'tt10687564'}
# {'_id': 'tt5232792'}
# {'_id': 'tt6970700'}
# {'_id': 'tt6468322'}
# {'_id': 'tt0096697'}
# {'_id': 'tt8427140'}
# {'_id': 'tt6712390'}
# {'_id': 'tt8398600'}
# {'_id': 'tt9251798'}
# {'_id': 'tt8652642'}
# {'_id': 'tt6210996'}
# {'_id': 'tt5066664'}
# {'_id': 'tt12137974'}
# {'_id': 'tt7462576'}
# {'_id': 'tt2661044'}
# {'_id': 'tt6315640'}
# {'_id': 'tt1254019'}
# {'_id': 'tt11301642'}
# {'_id': 'tt7691572'}
# {'_id': 'tt6111130'}
# {'_id': 'tt9839146'}
# {'_id': 'tt5555260'}
# {'_id': 'tt2660806'}
# {'_id': 'tt9055008'}
# {'_id': 'tt11243536'}
# {'_id': 'tt7959026'}
# {'_id': 'tt6470478'}
# {'_id': 'tt7695916'}
# {'_id': 'tt4179452'}
# {'_id': 'tt10577736'}
# {'_id': 'tt8634332'}
# {'_id': 'tt2372162'}
# {'_id': 'tt6762348'}
# {'_id': 'tt0369179'}
# {'_id': 'tt2177461'}
# {'_id': 'tt7340356'}
# {'_id': 'tt9173364'}
# {'_id': 'tt7053920'}
# {'_id': 'tt9307990'}
# {'_id': 'tt9342092'}
# {'_id': 'tt9742936'}
# {'_id': 'tt8707922'}
# {'_id': 'tt9070896'}
# {'_id': 'tt8335218'}
# {'_id': 'tt3749900'}
# {'_id': 'tt4270492'}
# {'_id': 'tt6905686'}
# {'_id': 'tt9486226'}
# {'_id': 'tt8103070'}
# {'_id': 'tt7053188'}
# {'_id': 'tt11212828'}
# {'_id': 'tt9067020'}
# {'_id': 'tt5616294'}
# {'_id': 'tt8575476'}
# {'_id': 'tt5071412'}
# {'_id': 'tt3322310'}
# {'_id': 'tt2455514'}
# {'_id': 'tt5834204'}
# {'_id': 'tt7939218'}
# {'_id': 'tt10311932'}
# {'_id': 'tt3865236'}
# {'_id': 'tt9281190'}
# {'_id': 'tt5715524'}
# {'_id': 'tt7908628'}
# {'_id': 'tt10244612'}
# {'_id': 'tt5607976'}
# {'_id': 'tt4304864'}
# {'_id': 'tt6526624'}
# {'_id': 'tt6905542'}
# {'_id': 'tt5809150'}
# {'_id': 'tt5016504'}
# {'_id': 'tt11621718'}
# {'_id': 'tt7606620'}
# {'_id': 'tt4644488'}
# {'_id': 'tt7596008'}
# {'_id': 'tt9315054'}
# {'_id': 'tt7028444'}
# {'_id': 'tt13269706'}
# {'_id': 'tt6868820'}
# {'_id': 'tt2805096'}
# {'_id': 'tt8001250'}
# {'_id': 'tt9612516'}
# {'_id': 'tt7971476'}
# {'_id': 'tt5900600'}
# {'_id': 'tt9308346'}
# {'_id': 'tt10936342'}
# {'_id': 'tt9340526'}
# {'_id': 'tt8826128'}
# {'_id': 'tt7821582'}
# {'_id': 'tt10293708'}
# {'_id': 'tt7826376'}
# {'_id': 'tt2741602'}
# {'_id': 'tt7216954'}
# {'_id': 'tt2261391'}
# {'_id': 'tt7826108'}
# {'_id': 'tt11968312'}
# {'_id': 'tt8806524'}
# {'_id': 'tt2149175'}
# {'_id': 'tt1796960'}
# {'_id': 'tt8712204'}
# {'_id': 'tt8000674'}
# {'_id': 'tt8655736'}
# {'_id': 'tt2261227'}
# {'_id': 'tt1051220'}
# {'_id': 'tt8040300'}
# {'_id': 'tt7049682'}
# {'_id': 'tt7942774'}
# {'_id': 'tt8463714'}
# {'_id': 'tt7967262'}
# {'_id': 'tt5363918'}
# {'_id': 'tt5171438'}
# {'_id': 'tt7949204'}
# {'_id': 'tt2708480'}
# {'_id': 'tt3107288'}
# {'_id': 'tt8741648'}
# {'_id': 'tt11004134'}
# {'_id': 'tt5614844'}
# {'_id': 'tt9348692'}
# {'_id': 'tt9426290'}
# {'_id': 'tt10473306'}
# {'_id': 'tt0413573'}
# {'_id': 'tt8880894'}
# {'_id': 'tt7134908'}
# {'_id': 'tt8421350'}
# {'_id': 'tt8403622'}
# {'_id': 'tt8332438'}
# {'_id': 'tt9698480'}
# {'_id': 'tt6714408'}
# {'_id': 'tt0437018'}
# {'_id': 'tt8295472'}
# {'_id': 'tt2575988'}
# {'_id': 'tt1830617'}
# {'_id': 'tt7645192'}
# {'_id': 'tt6611916'}
# {'_id': 'tt7671068'}
# {'_id': 'tt11937662'}
# {'_id': 'tt8390342'}
# {'_id': 'tt8297022'}
# {'_id': 'tt8923396'}
# {'_id': 'tt10986410'}
# {'_id': 'tt10601210'}
# {'_id': 'tt7772588'}
# {'_id': 'tt1885102'}
# {'_id': 'tt5675620'}
# {'_id': 'tt9048368'}
# {'_id': 'tt8382834'}
# {'_id': 'tt6110648'}
# {'_id': 'tt8068860'}
# {'_id': 'tt11160690'}
# {'_id': 'tt8593252'}
# {'_id': 'tt8289480'}
# {'_id': 'tt11215112'}
# {'_id': 'tt6257970'}
# {'_id': 'tt7671598'}
# {'_id': 'tt7942796'}
# {'_id': 'tt1740299'}
# {'_id': 'tt6183736'}
# {'_id': 'tt1399045'}
# {'_id': 'tt12987918'}
# {'_id': 'tt6625730'}
# {'_id': 'tt0182576'}
# {'_id': 'tt8905964'}
# {'_id': 'tt5707802'}
# {'_id': 'tt8201142'}
# {'_id': 'tt5192156'}
# {'_id': 'tt8165086'}
# {'_id': 'tt1502407'}
# {'_id': 'tt3602560'}
# {'_id': 'tt5420376'}
# {'_id': 'tt10329046'}
# {'_id': 'tt7767422'}
# {'_id': 'tt4699982'}
# {'_id': 'tt8385496'}
# {'_id': 'tt8923854'}
# {'_id': 'tt7909970'}
# {'_id': 'tt3339966'}
# {'_id': 'tt4154756'}
# {'_id': 'tt7393142'}
# {'_id': 'tt10759006'}
# {'_id': 'tt5180504'}
# {'_id': 'tt7335184'}
# {'_id': 'tt10312964'}
# {'_id': 'tt1844624'}
# {'_id': 'tt10293938'}
# {'_id': 'tt10715148'}
# {'_id': 'tt8741290'}
# {'_id': 'tt4276624'}
# {'_id': 'tt8416494'}
# {'_id': 'tt7588054'}
# {'_id': 'tt9253866'}
# {'_id': 'tt10517426'}
# {'_id': 'tt10677432'}
# {'_id': 'tt10186846'}
# {'_id': 'tt8755226'}
# {'_id': 'tt7083006'}
# {'_id': 'tt8134470'}
# {'_id': 'tt7587890'}
# {'_id': 'tt8778064'}
# {'_id': 'tt7366338'}
# {'_id': 'tt8271176'}
# {'_id': 'tt4555364'}
# {'_id': 'tt7651892'}
# {'_id': 'tt9100822'}
# {'_id': 'tt7403736'}
# {'_id': 'tt2193021'}
# {'_id': 'tt4396630'}
# {'_id': 'tt5562056'}
# {'_id': 'tt6964748'}
# {'_id': 'tt8111088'}
# {'_id': 'tt5973572'}
# {'_id': 'tt9165830'}
# {'_id': 'tt6394324'}
# {'_id': 'tt9148598'}
# {'_id': 'tt5687612'}
# {'_id': 'tt7958782'}
# {'_id': 'tt5210146'}
# {'_id': 'tt8115666'}
# {'_id': 'tt7949218'}
# Fim
